# %%
# 17BCB0090
# Rajat Gupta


# Task 6

# %%
import nltk
#nltk.download()

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize 
stop_words = set(stopwords.words('english')) 
sentence = "The little yellow dog ate the cat"

# %%
tokenized = sent_tokenize(sentence) 
for i in tokenized:
    wordsList = nltk.word_tokenize(i)
    wordsList = [w for w in wordsList if not w in stop_words] 
    tagged = nltk.pos_tag(wordsList)
    print(tagged)
# Out:
# [('The', 'DT'), ('little', 'JJ'), ('yellow', 'JJ'), ('dog', 'NN'), ('ate', 'NN'), ('cat', 'NN')]

# %%
#sentence = [("The", "DT"), ("little", "JJ"), ("yellow", "JJ")]
#sentence = "The little yellow dog ate the cat"
#sentence = nltk.word_tokenize(sentence)

grammar = "NP: {<DT>?<JJ>*<NN>}"

# %%
cp = nltk.RegexpParser(grammar)

# %%
result = cp.parse(tagged)

# %%
print(result)
# Out:
# (S (NP The/DT little/JJ yellow/JJ dog/NN) (NP ate/NN) (NP cat/NN))

# %%
result.draw()

# %%
conda install -c conda-forge spacy
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - spacy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     catalogue-1.0.0            |             py_0          10 KB  conda-forge
#     conda-4.8.2                |           py37_0         3.0 MB  conda-forge
#     cymem-2.0.3                |   py37h6538335_0          35 KB  conda-forge
#     cython-blis-0.4.1          |   py37hfa6e2cd_0         4.3 MB  conda-forge
#     murmurhash-1.0.0           |   py37h6538335_0          17 KB  conda-forge
#     plac-0.9.6                 |           py37_0          38 KB
#     preshed-3.0.2              |   py37h6538335_1          89 KB  conda-forge
#     spacy-2.2.3                |   py37he980bc4_0         7.9 MB  conda-forge
# ...

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-e4c801bd61f2> in <module>
# ----> 1 import spacy
#       2 nlp = spacy.load('en_core_web_sm')
#
# ModuleNotFoundError: No module named 'spacy'

# %%
examle = "The Natural Language Toolkit (NLTK) is a platform used for building programs for text analysis. One of the more powerful aspects of the NLTK module is the Part of Speech tagging."
doc = nlp(example)
for ent i doc.ents:
    print(ent.text, ent.label_)
